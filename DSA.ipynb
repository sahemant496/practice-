# %% [markdown]
# <a href="https://colab.research.google.com/github/sahemant496/practice-/blob/main/DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= "Hemant"
b = a[1:7:2]
print(b)
# Out:
# eat

# %%
x = [3, 12, 7, 25, 9]
largest = x[0]
for num in x:
  if num > largest:
    largest = num


print(largest)
# Out:
# 25

# %%
x = [1, 4, 7, 8, 10, 13]
count = 0
for num in x:
  if(num%2==0):
    coun

# %%
x = int(input("Enter the number: "))
for i in range(1, 11):
  print(f"{x}x{i}={x*i}",end=" ")
# Out:
# Enter the number: 5
# 5x1=5 5x2=10 5x3=15 5x4=20 5x5=25 5x6=30 5x7=35 5x8=40 5x9=45 5x10=50

# %%
from IPython.core.inputtransformer2 import ESCAPE_SINGLES
x =[10, -5, 0, 7, -2, 0, 8]
p_c=0
n_c=0
zero=0

for num in x:
  if(num>0):
    p_c+=1

  elif(num<0):
    n_c+=1

  else:
    zero+=1

print(f"Positive: {p_c} Negative: {n_c} Zero: {zero}")
# Out:
# Positive: 3 Negitive: 2 Zero: 2

# %%
x= 12345
y=str(x)
a=y[::-1]
print(int(a))

# i=4
# while(i>=0):
#   print(y[i],end="")
#   i-=1
# Out:
# 54321
